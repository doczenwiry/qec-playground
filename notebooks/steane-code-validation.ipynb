# %%
import itertools
import stim

from utils.circuit_expectations import compute_stabilizer_expectation, compute_observable_expectation
from utils.circuit_flows import check_syndrome_extraction, check_flow_preservation
from utils.noise_annotation import annotate_noise

# %%
circuit = stim.Circuit.from_file("../assets/steane-code/steane-code-standard-syndrome-measurement.stim")
supports = {
    'R' : [5, 6, 8, 9],
    'G' : [0, 3, 5, 8],
    'B' : [0, 1, 5, 6],
}

print(f"Stabilizer flows")
for stabilizer, support in itertools.product(['X', 'Z'], supports.values()):
    check_flow_preservation(circuit, stabilizer, support)
print(f"Observable flows")
for observable in ['X', 'Y', 'Z']:
    check_flow_preservation(circuit, observable, support=[0, 1, 3, 5, 6, 8, 9])
print(f"Syndrome extractions")
for syndrome, support in itertools.product(['X', 'Z'], supports.values()):
    check_syndrome_extraction(circuit, syndrome, support)

# %%
circuit = stim.Circuit.from_file("../assets/steane-code/steane-code-standard-syndrome-measurement.annotated.stim")
supports = {
    'R' : [5, 6, 8, 9],
    'G' : [0, 3, 5, 8],
    'B' : [0, 1, 5, 6],
}

noisy = annotate_noise(circuit)

result = noisy.search_for_undetectable_logical_errors(
    dont_explore_detection_event_sets_with_size_above=4,
    dont_explore_edges_with_degree_above=3,
    dont_explore_edges_increasing_symptom_degree=False,
)

print(f"Minimal undetected logical error : {len(result)}")
for loc in result:
    print(loc)

# %%
circuit = stim.Circuit.from_file("../assets/steane-code/steane-code-superdense-syndrome-measurement.bell.stim")
supports = {
    'R' : [6, 7, 11, 12],
    'G' : [0, 5, 6, 11],
    'B' : [0, 1, 6, 7],
}

print(f"Stabilizer flows")
for stabilizer, support in itertools.product(['X', 'Z'], supports.values()):
    check_flow_preservation(circuit, stabilizer, support)
print(f"Observable flows")
for observable in ['X', 'Y', 'Z']:
    check_flow_preservation(circuit, observable, support=[0, 1, 5, 6, 7, 11, 12])
print(f"Syndrome extractions")
for syndrome, support in itertools.product(['X', 'Z'], supports.values()):
    check_syndrome_extraction(circuit, syndrome, support)

# %%
circuit = stim.Circuit.from_file(
    "../assets/steane-code/steane-code-superdense-syndrome-measurement.bell.annotated.stim")
supports = {
    'R' : [5, 6, 8, 9],
    'G' : [0, 3, 5, 8],
    'B' : [0, 1, 5, 6],
}

noisy = annotate_noise(circuit)

result = noisy.search_for_undetectable_logical_errors(
    dont_explore_detection_event_sets_with_size_above=4,
    dont_explore_edges_with_degree_above=3,
    dont_explore_edges_increasing_symptom_degree=False,
)

print(f"Minimal undetected logical error : {len(result)}")
for loc in result:
    print(loc)

# %%
circuit = stim.Circuit.from_file("../assets/steane-code/steane-code-superdense-syndrome-measurement.ghz.stim")
supports = {
    'R' : [8, 9, 14, 15],
    'G' : [0, 6, 8, 14],
    'B' : [0, 1, 8, 9],
}

print(f"Stabilizer flows")
for stabilizer, support in itertools.product(['X', 'Z'], supports.values()):
    check_flow_preservation(circuit, stabilizer, support)
print(f"Observable flows")
for observable in ['X', 'Y', 'Z']:
    check_flow_preservation(circuit, observable, support=[0, 1, 6, 8, 9, 14, 15])
print(f"Syndrome extractions")
for syndrome, support in itertools.product(['X', 'Z'], supports.values()):
    check_syndrome_extraction(circuit, syndrome, support)

# %%
circuit = stim.Circuit.from_file("../assets/steane-code/steane-code-superdense-syndrome-measurement.ghz.annotated.stim")
supports = {
    'R' : [8, 9, 14, 15],
    'G' : [0, 6, 8, 14],
    'B' : [0, 1, 8, 9],
}

noisy = annotate_noise(circuit)

result = noisy.search_for_undetectable_logical_errors(
    dont_explore_detection_event_sets_with_size_above=4,
    dont_explore_edges_with_degree_above=3,
    dont_explore_edges_increasing_symptom_degree=False,
)

print(f"Minimal undetected logical error : {len(result)}")
for loc in result:
    print(loc)

# %%
circuit = stim.Circuit.from_file("../assets/steane-code/steane-code-superdense-syndrome-measurement.ghz.v2.stim")
supports = {
    'R' : [8, 9, 14, 15],
    'G' : [0, 6, 8, 14],
    'B' : [0, 1, 8, 9],
}

print(f"Stabilizer flows")
for stabilizer, support in itertools.product(['X', 'Z'], supports.values()):
    check_flow_preservation(circuit, stabilizer, support)
print(f"Observable flows")
for observable in ['X', 'Y', 'Z']:
    check_flow_preservation(circuit, observable, support=[0, 1, 6, 8, 9, 14, 15])
print(f"Syndrome extractions")
for syndrome, support in itertools.product(['X', 'Z'], supports.values()):
    check_syndrome_extraction(circuit, syndrome, support)

# %%
design = stim.Circuit.from_file("../assets/steane-code/steane-code-prepared-superdense-syndrome-measurement.bell.stim")
supports = {
    'R' : [6, 7, 11, 12],
    'G' : [0, 5, 6, 11],
    'B' : [0, 1, 6, 7],
}
compute_stabilizer_expectation(design, supports)
compute_observable_expectation(design, observable='X', support=[0, 1, 5, 6, 7, 11, 12])

# %%
design = stim.Circuit.from_file(
    "../assets/steane-code/steane-code-prepared-superdense-syndrome-measurement.bell.v2.stim")
supports = {
    'R' : [6, 7, 11, 12],
    'G' : [0, 5, 6, 11],
    'B' : [0, 1, 6, 7],
}
compute_stabilizer_expectation(design, supports)
compute_observable_expectation(design, observable='X', support=[0, 1, 5, 6, 7, 11, 12])
